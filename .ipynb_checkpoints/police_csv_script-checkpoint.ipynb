# %%
# %matplotlib notebook

# %%
import requests
import json
import gmaps
import matplotlib as plt
from config import (gkey)
from pprint import pprint
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt

# %%
zip_crime_csv = "Resources/police_data.csv"
zip_crime_reader = pd.read_csv(zip_crime_csv, encoding="ISO-8859-1")
zip_crime_reader.head(2)
# Out:
#   Incident Number w/year  Year of Incident  Watch  \
# 0            038164-2018              2018      3
# 1            066284-2018              2018      1
#
#              Call (911) Problem                         Type of Incident  \
# 0  6XEA - DISTURBANCE EMERG AMB        RESIST ARREST SEARCH OR TRANSPORT
# 1    6X - MAJOR DIST (VIOLENCE)  ASSAULT -PUB SERV (PEACE OFFICER/JUDGE)
#
#   Date1 of Occurrence Month1 of Occurence Day1 of the Week  \
# 0           2/21/2018            February              Wed
# 1           3/30/2018               March              Fri
#
#   Time1 of Occurrence Call Dispatch Date Time  X Coordinate  Y Cordinate  \
# 0               19:30         2/21/2018 19:41           NaN          NaN
# 1               01:40         3/30/2018 01:27           NaN          NaN
#
#    Zip Code City State
# 0       NaN  NaN   NaN
# 1       NaN  NaN   NaN

# %%
zip_crime_reader.count()
# Out:
# Incident Number w/year     133949
# Year of Incident           133949
# Watch                      133949
# Call (911) Problem         132683
# Type of Incident           133949
# Date1 of Occurrence        133949
# Month1 of Occurence        133949
# Day1 of the Week           133949
# Time1 of Occurrence        133949
# Call Dispatch Date Time    132673
# X Coordinate                98503
# Y Cordinate                 98503
# Zip Code                   133669
# City                       132123
# State                      132974
# dtype: int64

# %%
zip_crime_dropped = zip_crime_reader.dropna(how='any')
zip_crime_dropped.count()
# Out:
# Incident Number w/year     95440
# Year of Incident           95440
# Watch                      95440
# Call (911) Problem         95440
# Type of Incident           95440
# Date1 of Occurrence        95440
# Month1 of Occurence        95440
# Day1 of the Week           95440
# Time1 of Occurrence        95440
# Call Dispatch Date Time    95440
# X Coordinate               95440
# Y Cordinate                95440
# Zip Code                   95440
# City                       95440
# State                      95440
# dtype: int64

# %%
zip_crime_dropped.columns
# Out:
# Index(['Incident Number w/year', 'Year of Incident', 'Watch',
#        'Call (911) Problem', 'Type of Incident', 'Date1 of Occurrence',
#        'Month1 of Occurence', 'Day1 of the Week', 'Time1 of Occurrence',
#        'Call Dispatch Date Time', 'X Coordinate', 'Y Cordinate', 'Zip Code',
#        'City', 'State'],
#       dtype='object')

# %%
zip_crime_dropped.dtypes
# Out:
# Incident Number w/year      object
# Year of Incident             int64
# Watch                        int64
# Call (911) Problem          object
# Type of Incident            object
# Date1 of Occurrence         object
# Month1 of Occurence         object
# Day1 of the Week            object
# Time1 of Occurrence         object
# Call Dispatch Date Time     object
# X Coordinate               float64
# Y Cordinate                float64
# Zip Code                   float64
# City                        object
# State                       object
# dtype: object

# %%
zip_crime_dropped['Zip Code'] = zip_crime_dropped['Zip Code'].astype(object)
zip_crime_dropped['Zip Code'].dtype
zip_crime_dropped.dtypes
# Out:
# C:\Users\btech\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# Incident Number w/year      object
# Year of Incident             int64
# Watch                        int64
# Call (911) Problem          object
# Type of Incident            object
# Date1 of Occurrence         object
# Month1 of Occurence         object
# Day1 of the Week            object
# Time1 of Occurrence         object
# Call Dispatch Date Time     object
# X Coordinate               float64
# Y Cordinate                float64
# Zip Code                    object
# City                        object
# State                       object
# dtype: object

# %%
zip_crime_df = zip_crime_dropped.loc[:, ["Zip Code", "X Coordinate", "Y Cordinate", "City", "Type of Incident"]]
zip_crime_renamed_df = zip_crime_df.rename(columns={"Zip Code": "Zip Code","X Coordinate": "Longitude", "Y Cordinate": "Latitude", "City": "City","Type of Incident":"Type of Crime"})
zip_crime_renamed_df.head(10)
# Out:
#     Zip Code    Longitude     Latitude    City  \
# 205    75212  2476498.585  6971715.153  DALLAS
# 212    75253  2548241.858  6932130.126  DALLAS
# 219    75217  2525365.155  6960102.895  DALLAS
# 221    75216  2496126.907  6941940.628  DALLAS
# 222    75216  2487800.730  6937829.316  DALLAS
# 229    75211  2468877.713  6961189.651  DALLAS
# 230    75204  2494114.098  6976578.343  DALLAS
# 231    75215  2492637.330  6968271.897  DALLAS
# 233    75217  2524662.487  6947002.514  DALLAS
# 234    75210  2510456.676  6966237.837  DALLAS
#
#                                          Type of Crime
# 205                   VIO PROTECT ORDER BIAS/PREJUDICE
# 212                    ABANDONED PROPERTY (NO OFFENSE)
# 219                                PUBLIC INTOXICATION
# 221                        ASSAULT -BODILY INJURY ONLY
# 222                   WARRANT-DALLAS PD (ALIAS/CAPIAS)
# 229  UNAUTHORIZED USE OF MOTOR VEH - (ATT) TRUCK OR...
# 230              CRIM MISCHIEF >OR EQUAL $750 < $2,500
# 231                                PUBLIC INTOXICATION
# 233                  FAIL TO ID -FUGITIVE FROM JUSTICE
# 234                                    DWI 1 PREV CONV

# %%
unique_crimes = len(zip_crime_renamed_df["Type of Crime"].unique())
unique_zip = len(zip_crime_renamed_df["Zip Code"].unique())
unique_zipcrimes = pd.DataFrame({"Number of Unique ZipCodes": [unique_zip] , "Number of Unique Crimes": [unique_crimes] })
unique_zipcrimes
# Out:
#    Number of Unique ZipCodes  Number of Unique Crimes
# 0                         81                      549

# %%
#warnings.simplefilter(action='ignore', category=FutureWarning)
#print('x' in np.arange(5))   #returns False, without Warning

zip_city = zip_crime_renamed_df["City"].value_counts()
zip_city
#zip_crime_loc = zip_crime_renamed_df.loc[zip_crime_renamed_df["City"] == "Garland"]
#zip_crime_loc


#zip_crime_loc = zip_crime_renamed_df.loc[(zip_crime_renamed_df["Zip Code"] == "PUBLIC INTOXICATION") | (zip_crime_renamed_df["Zip Code"] == "ASSAULT -BODILY INJURY ONLY"),:]
#print(zip_crime_loc)
# Out:
# DALLAS             94902
# Dallas               227
# GARLAND               46
# DAL                   32
# MESQUITE              30
# DUNCANVILLE           26
# RICHARDSON            26
# DESOTO                21
# DALLLAS               19
# CARROLLTON            18
# ROWLETT               17
# DLS                   12
# IRVING                 8
# DALAS                  7
# LANCASTER              7
# COPPELL                6
# GRAND PRAIRIE          4
# DALLS                  4
# PLANO                  4
# GRAND PRAI             3
# SEAGOVILLE             3
# UNIVERSITY PARK        3
# CEDAR HILL             3
# ADDISON                3
# FARMERSBRA             1
# RED OAK                1
# DALLASS                1
# DALALAS                1
# ALICE                  1
# DALALS                 1
# DALLAS TX              1
# DA                     1
# DUNCANVILL             1
# Name: City, dtype: int64

# %%
zip_crime_changed_df = zip_crime_renamed_df.replace({"Dallas": "DALLAS","DAL": "DALLAS", "DALLLAS": "DALLAS","DALLLAS": "DALLAS","DLS": "DALLAS","DALAS": "DALLAS","DALLS": "DALLAS","DALLAS TX": "DALLAS","DALALS": "DALLAS","DA": "DALLAS","DALLASS": "DALLAS","DALALAS": "DALLAS", "GRAND PRAI": "GRAND PRAIRIE"})
zip_crime_changed_df["City"].value_counts()
# Out:
# DALLAS             95208
# GARLAND               46
# MESQUITE              30
# DUNCANVILLE           26
# RICHARDSON            26
# DESOTO                21
# CARROLLTON            18
# ROWLETT               17
# IRVING                 8
# GRAND PRAIRIE          7
# LANCASTER              7
# COPPELL                6
# PLANO                  4
# SEAGOVILLE             3
# CEDAR HILL             3
# ADDISON                3
# UNIVERSITY PARK        3
# ALICE                  1
# DUNCANVILL             1
# RED OAK                1
# FARMERSBRA             1
# Name: City, dtype: int64

# %%
dallas_crime_df = zip_crime_changed_df.loc[zip_crime_changed_df["City"] == "DALLAS"]
rowlett_crime_df = zip_crime_changed_df.loc[zip_crime_changed_df["City"] == "ROWLETT"]
plano_crime_df = zip_crime_changed_df.loc[zip_crime_changed_df["City"] == "PLANO"]
carrollton_crime_df = zip_crime_changed_df.loc[zip_crime_changed_df["City"] == "CARROLLTON"]

# or just len() for total crimes
#unique_crimes_dallas = len(dallas_crime_df["Type of Crime"].unique())             
unique_crimes_dallas = dallas_crime_df["Type of Crime"]
unique_crimes_rowlett = len(rowlett_crime_df["Type of Crime"].unique())
#unique_crimes_plano = len(plano_crime_df["Type of Crime"].unique())
unique_crimes_plano = plano_crime_df["Type of Crime"]
unique_crimes_carrollton = len(carrollton_crime_df["Type of Crime"].unique())


unique_city_crimes = pd.DataFrame({"Total Unique Dallas Crimes": [unique_crimes_dallas], "Total Unique Plano Crimes":[unique_crimes_plano] })
unique_city_crimes.head(20)

#Need to do this for different Dallas Zip Code locations
#Create DataFrame with header City or Zip/Total Crimes in 2018/percent within the entire metroplex of citys or Zipcodes in Dallas
#Bar / Line / Heat?
#Transpose Zips?
# Out:
#                           Total Unique Dallas Crimes  \
# 0  205                        VIO PROTECT ORDER B...
#
#                            Total Unique Plano Crimes
# 0  25841      UNAUTHORIZED USE OF MOTOR VEH - (AT...

# %%
dallas_crime_df = zip_crime_changed_df.loc[zip_crime_changed_df["City"] == "DALLAS"]
dallas_crime_df.head(10)
# Out:
#      Zip Code    Longitude     Latitude    City  \
# 205   75212.0  2476498.585  6971715.153  DALLAS
# 212   75253.0  2548241.858  6932130.126  DALLAS
# 219   75217.0  2525365.155  6960102.895  DALLAS
# 221   75216.0  2496126.907  6941940.628  DALLAS
# 222   75216.0  2487800.730  6937829.316  DALLAS
# 229   75211.0  2468877.713  6961189.651  DALLAS
# 230   75204.0  2494114.098  6976578.343  DALLAS
# 231   75215.0  2492637.330  6968271.897  DALLAS
# 233   75217.0  2524662.487  6947002.514  DALLAS
# 234   75210.0  2510456.676  6966237.837  DALLAS
#
#                                          Type of Crime
# 205                   VIO PROTECT ORDER BIAS/PREJUDICE
# 212                    ABANDONED PROPERTY (NO OFFENSE)
# 219                                PUBLIC INTOXICATION
# 221                        ASSAULT -BODILY INJURY ONLY
# 222                   WARRANT-DALLAS PD (ALIAS/CAPIAS)
# 229  UNAUTHORIZED USE OF MOTOR VEH - (ATT) TRUCK OR...
# 230              CRIM MISCHIEF >OR EQUAL $750 < $2,500
# 231                                PUBLIC INTOXICATION
# 233                  FAIL TO ID -FUGITIVE FROM JUSTICE
# 234                                    DWI 1 PREV CONV

# %%
dallas_crime_df['Zip Code'] = dallas_crime_df['Zip Code'].astype(object)
dallas_crime_df['Zip Code'].dtype
dallas_crime_df.dtypes
dallas_crime_df.head(10)
# Out:
# C:\Users\btech\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     Zip Code    Longitude     Latitude    City  \
# 205    75212  2476498.585  6971715.153  DALLAS
# 212    75253  2548241.858  6932130.126  DALLAS
# 219    75217  2525365.155  6960102.895  DALLAS
# 221    75216  2496126.907  6941940.628  DALLAS
# 222    75216  2487800.730  6937829.316  DALLAS
# 229    75211  2468877.713  6961189.651  DALLAS
# 230    75204  2494114.098  6976578.343  DALLAS
# 231    75215  2492637.330  6968271.897  DALLAS
# 233    75217  2524662.487  6947002.514  DALLAS
# 234    75210  2510456.676  6966237.837  DALLAS
#
#                                          Type of Crime
# 205                   VIO PROTECT ORDER BIAS/PREJUDICE
# 212                    ABANDONED PROPERTY (NO OFFENSE)
# 219                                PUBLIC INTOXICATION
# 221                        ASSAULT -BODILY INJURY ONLY
# 222                   WARRANT-DALLAS PD (ALIAS/CAPIAS)
# 229  UNAUTHORIZED USE OF MOTOR VEH - (ATT) TRUCK OR...
# 230              CRIM MISCHIEF >OR EQUAL $750 < $2,500
# 231                                PUBLIC INTOXICATION
# 233                  FAIL TO ID -FUGITIVE FROM JUSTICE
# 234                                    DWI 1 PREV CONV

# %%
dallas_zip_crime = dallas_crime_df.loc[:, ["Zip Code", "Type of Crime"]]
dallas_zip_crime
# Out:
#        Zip Code                                      Type of Crime
# 205       75212                   VIO PROTECT ORDER BIAS/PREJUDICE
# 212       75253                    ABANDONED PROPERTY (NO OFFENSE)
# 219       75217                                PUBLIC INTOXICATION
# 221       75216                        ASSAULT -BODILY INJURY ONLY
# 222       75216                   WARRANT-DALLAS PD (ALIAS/CAPIAS)
# 229       75211  UNAUTHORIZED USE OF MOTOR VEH - (ATT) TRUCK OR...
# 230       75204              CRIM MISCHIEF >OR EQUAL $750 < $2,500
# 231       75215                                PUBLIC INTOXICATION
# 233       75217                  FAIL TO ID -FUGITIVE FROM JUSTICE
# 234       75210                                    DWI 1 PREV CONV
# 236       75224  INJURED PERSON- PUBLIC PROPERTY (OTHER THAN FI...
# 237       75217               CRIM MISCHIEF > OR EQUAL $100 < $750
# 239       75224                              ROBBERY OF INDIVIDUAL
# 240       75206                 ALARM INCIDENT REPORT (NO OFFENSE)
# 241       75204               CRIM MISCHIEF > OR EQUAL $100 < $750
# 242       75228                        FOUND PROPERTY (NO OFFENSE)
# 246       75229                BURGLARY OF BUILDING - FORCED ENTRY
# 247       75232        FRAUD USE/POSS IDENTIFYING INFO # ITEMS < 5
# 248       75236         UNAUTHORIZED USE OF MOTOR VEH - AUTOMOBILE
# 249       75237                                PUBLIC INTOXICATION
# 250       75211       UNAUTHORIZED USE OF MOTOR VEH - TRUCK OR BUS
# 252       75206                 ALARM INCIDENT REPORT (NO OFFENSE)
# 253       75227                      WARRANT HOLD (OUTSIDE AGENCY)
# 254       75252              CRIM MISCHIEF >OR EQUAL $750 < $2,500
# 255       75217                                         HARASSMENT
# 256       75216                       ASSAULT (AGG) -DEADLY WEAPON
# 257       75226                                                BMV
# 258       75206                 ALARM INCIDENT REPORT (NO OFFENSE)
# 259       75204                    ABANDONED PROPERTY (NO OFFENSE)
# 260       75247  THEFT OF PROP > OR EQUAL $2,500 <$30K (NOT SHO...
# ...         ...                                                ...
# 133905    75201                                    RECKLESS DAMAGE
# 133907    75215                        FOUND PROPERTY (NO OFFENSE)
# 133908    75238              BURGLARY OF HABITATION - FORCED ENTRY
# 133909    75227               CRIM MISCHIEF > OR EQUAL $100 < $750
# 133910    75240                         LOST PROPERTY (NO OFFENSE)
# 133912    75238                    ABANDONED PROPERTY (NO OFFENSE)
# 133913    75224       UNAUTHORIZED USE OF MOTOR VEH - TRUCK OR BUS
# 133914    75215                     UNLAWFUL POSS FIREARM BY FELON
# 133915    75220                          CRIMINAL TRESPASS WARNING
# 133917    75216  THEFT OF PROP > OR EQUAL $2,500 <$30K (NOT SHO...
# 133918    75226                   WARRANT-DALLAS PD (ALIAS/CAPIAS)
# 133919    75211                                         HARASSMENT
# 133920    75217                      WARRANT HOLD (OUTSIDE AGENCY)
# 133921    75215                   WARRANT-DALLAS PD (ALIAS/CAPIAS)
# 133922    75237         UNAUTHORIZED USE OF MOTOR VEH - AUTOMOBILE
# 133923    75241                                   ARSON -MOTOR VEH
# 133924    75217         UNAUTHORIZED USE OF MOTOR VEH - AUTOMOBILE
# 133925    75218              CRIM MISCHIEF >OR EQUAL $750 < $2,500
# 133927    75253                                                BMV
# 133929    75237               CRIM MISCHIEF > OR EQUAL $100 < $750
# 133931    75219                                                BMV
# 133933    75226                    ABANDONED PROPERTY (NO OFFENSE)
# 133935    75226                             POSS OF DANGEROUS DRUG
# 133938    75209  THEFT OF PROP > OR EQUAL $2,500 <$30K (NOT SHO...
# 133941    75212                       ASSAULT (AGG) -DEADLY WEAPON
# 133942    75202             BURGLARY OF BUILDING - NO FORCED ENTRY
# 133944    75224               CRIM MISCHIEF > OR EQUAL $100 < $750
# 133946    75241  THEFT OF PROP > OR EQUAL $100 <$750 (NOT SHOPL...
# 133947    75216         UNAUTHORIZED USE OF MOTOR VEH - AUTOMOBILE
# 133948    75216          THEFT OF PROP <$100 - OTHER THAN SHOPLIFT
#
# [95208 rows x 2 columns]

# %%
total_crimes_per_zip = dallas_zip_crime["Zip Code"].value_counts()
total_crimes_per_zip
# Out:
# 75216.0    5683
# 75217.0    5326
# 75228.0    4898
# 75220.0    4690
# 75243.0    4231
# 75215.0    4131
# 75211.0    3896
# 75227.0    3428
# 75201.0    3102
# 75204.0    3091
# 75241.0    2992
# 75231.0    2985
# 75229.0    2603
# 75226.0    2474
# 75224.0    2406
# 75237.0    2362
# 75206.0    2280
# 75212.0    2139
# 75208.0    1996
# 75232.0    1951
# 75202.0    1837
# 75287.0    1837
# 75240.0    1757
# 75235.0    1720
# 75203.0    1717
# 75210.0    1710
# 75219.0    1662
# 75238.0    1460
# 75214.0    1266
# 75247.0    1188
#            ...
# 75249.0     413
# 75234.0     333
# 75244.0     322
# 75246.0     275
# 75205.0     224
# 75019.0      27
# 75042.0      25
# 75116.0      23
# 75081.0      16
# 75040.0      14
# 75088.0      14
# 75051.0      12
# 75134.0      10
# 75115.0      10
# 75089.0      10
# 75052.0       8
# 75150.0       7
# 75159.0       7
# 75149.0       7
# 75050.0       6
# 75060.0       6
# 75062.0       5
# 75007.0       4
# 75080.0       4
# 75154.0       2
# 75126.0       1
# 75041.0       1
# 75137.0       1
# 75181.0       1
# 75063.0       1
# Name: Zip Code, Length: 73, dtype: int64

# %%
total_crimes_per_zip_df = total_crimes_per_zip.rename_axis('unique_values').reset_index(name='counts')
print (total_crimes_per_zip_df)
# Out:
#     unique_values  counts
# 0         75216.0    5683
# 1         75217.0    5326
# 2         75228.0    4898
# 3         75220.0    4690
# 4         75243.0    4231
# 5         75215.0    4131
# 6         75211.0    3896
# 7         75227.0    3428
# 8         75201.0    3102
# 9         75204.0    3091
# 10        75241.0    2992
# 11        75231.0    2985
# 12        75229.0    2603
# 13        75226.0    2474
# 14        75224.0    2406
# 15        75237.0    2362
# 16        75206.0    2280
# 17        75212.0    2139
# 18        75208.0    1996
# 19        75232.0    1951
# 20        75202.0    1837
# 21        75287.0    1837
# 22        75240.0    1757
# 23        75235.0    1720
# 24        75203.0    1717
# 25        75210.0    1710
# 26        75219.0    1662
# 27        75238.0    1460
# 28        75214.0    1266
# 29        75247.0    1188
# ..            ...     ...
# 43        75249.0     413
# 44        75234.0     333
# 45        75244.0     322
# 46        75246.0     275
# 47        75205.0     224
# 48        75019.0      27
# 49        75042.0      25
# 50        75116.0      23
# 51        75081.0      16
# 52        75040.0      14
# 53        75088.0      14
# 54        75051.0      12
# 55        75134.0      10
# 56        75115.0      10
# 57        75089.0      10
# 58        75052.0       8
# 59        75150.0       7
# 60        75159.0       7
# 61        75149.0       7
# 62        75050.0       6
# 63        75060.0       6
# 64        75062.0       5
# 65        75007.0       4
# 66        75080.0       4
# 67        75154.0       2
# 68        75126.0       1
# 69        75041.0       1
# 70        75137.0       1
# 71        75181.0       1
# 72        75063.0       1
#
# [73 rows x 2 columns]

# %%
zip_crime_count_df = pd.DataFrame(total_crimes_per_zip_df)
zip_crime_count_renamed = zip_crime_count_df.rename(columns={"unique_values": "Dallas Zip Codes","counts": "Total Number of Crimes Reported In 2018"})
zip_crime_count_renamed['Dallas Zip Codes'] = zip_crime_count_renamed['Dallas Zip Codes'].astype(object)
zip_crime_count_renamed
# Out:
#    Dallas Zip Codes  Total Number of Crimes Reported In 2018
# 0             75216                                     5683
# 1             75217                                     5326
# 2             75228                                     4898
# 3             75220                                     4690
# 4             75243                                     4231
# 5             75215                                     4131
# 6             75211                                     3896
# 7             75227                                     3428
# 8             75201                                     3102
# 9             75204                                     3091
# 10            75241                                     2992
# 11            75231                                     2985
# 12            75229                                     2603
# 13            75226                                     2474
# 14            75224                                     2406
# 15            75237                                     2362
# 16            75206                                     2280
# 17            75212                                     2139
# 18            75208                                     1996
# 19            75232                                     1951
# 20            75202                                     1837
# 21            75287                                     1837
# 22            75240                                     1757
# 23            75235                                     1720
# 24            75203                                     1717
# 25            75210                                     1710
# 26            75219                                     1662
# 27            75238                                     1460
# 28            75214                                     1266
# 29            75247                                     1188
# ..              ...                                      ...
# 43            75249                                      413
# 44            75234                                      333
# 45            75244                                      322
# 46            75246                                      275
# 47            75205                                      224
# 48            75019                                       27
# 49            75042                                       25
# 50            75116                                       23
# 51            75081                                       16
# 52            75040                                       14
# 53            75088                                       14
# 54            75051                                       12
# 55            75134                                       10
# 56            75115                                       10
# 57            75089                                       10
# 58            75052                                        8
# 59            75150                                        7
# 60            75159                                        7
# 61            75149                                        7
# 62            75050                                        6
# 63            75060                                        6
# 64            75062                                        5
# 65            75007                                        4
# 66            75080                                        4
# 67            75154                                        2
# 68            75126                                        1
# 69            75041                                        1
# 70            75137                                        1
# 71            75181                                        1
# 72            75063                                        1
#
# [73 rows x 2 columns]

# %%
zip_divisor = zip_crime_count_renamed['Total Number of Crimes Reported In 2018'].sum()
zip_numerator = zip_crime_count_renamed['Total Number of Crimes Reported In 2018']
crime_rate = (zip_numerator / zip_divisor) * 100
zip_crime_count_renamed[" Crime Rate (%)" ] = crime_rate
zip_crime_count_renamed


# Convert To Percent
# Crime Rate percentages are accurate but small due to the total amount of zipcodes we are comparing
# Maybe shrink number of zipcodes or merge them based on area in a new DataFrame

#percent_check = zip_crime_count_renamed["Crime Rate(%)" ].sum()
#percent_check
# Out:
#    Dallas Zip Codes  Total Number of Crimes Reported In 2018   Crime Rate (%)
# 0             75216                                     5683         5.969036
# 1             75217                                     5326         5.594068
# 2             75228                                     4898         5.144526
# 3             75220                                     4690         4.926057
# 4             75243                                     4231         4.443954
# 5             75215                                     4131         4.338921
# 6             75211                                     3896         4.092093
# 7             75227                                     3428         3.600538
# 8             75201                                     3102         3.258130
# 9             75204                                     3091         3.246576
# 10            75241                                     2992         3.142593
# 11            75231                                     2985         3.135241
# 12            75229                                     2603         2.734014
# 13            75226                                     2474         2.598521
# 14            75224                                     2406         2.527099
# 15            75237                                     2362         2.480884
# 16            75206                                     2280         2.394757
# 17            75212                                     2139         2.246660
# 18            75208                                     1996         2.096462
# 19            75232                                     1951         2.049198
# 20            75202                                     1837         1.929460
# 21            75287                                     1837         1.929460
# 22            75240                                     1757         1.845433
# 23            75235                                     1720         1.806571
# 24            75203                                     1717         1.803420
# 25            75210                                     1710         1.796068
# 26            75219                                     1662         1.745652
# 27            75238                                     1460         1.533485
# 28            75214                                     1266         1.329720
# 29            75247                                     1188         1.247794
# ..              ...                                      ...              ...
# 43            75249                                      413         0.433787
# 44            75234                                      333         0.349761
# 45            75244                                      322         0.338207
# 46            75246                                      275         0.288841
# 47            75205                                      224         0.235274
# 48            75019                                       27         0.028359
# 49            75042                                       25         0.026258
# 50            75116                                       23         0.024158
# 51            75081                                       16         0.016805
# 52            75040                                       14         0.014705
# 53            75088                                       14         0.014705
# 54            75051                                       12         0.012604
# 55            75134                                       10         0.010503
# 56            75115                                       10         0.010503
# 57            75089                                       10         0.010503
# 58            75052                                        8         0.008403
# 59            75150                                        7         0.007352
# 60            75159                                        7         0.007352
# 61            75149                                        7         0.007352
# 62            75050                                        6         0.006302
# 63            75060                                        6         0.006302
# 64            75062                                        5         0.005252
# 65            75007                                        4         0.004201
# 66            75080                                        4         0.004201
# 67            75154                                        2         0.002101
# 68            75126                                        1         0.001050
# 69            75041                                        1         0.001050
# 70            75137                                        1         0.001050
# 71            75181                                        1         0.001050
# 72            75063                                        1         0.001050
#
# [73 rows x 3 columns]

# %%
dallas_crimes_per_zip = pd.DataFrame({
    "Dallas District": ["Uptown / Main Street District / Dallas Farmers Market", 
                        "Dallas Design District", 
                        "Baylor", 
                        "Dallas Arts District", 
                        "West Dallas", 
                        "Oak Cliff",
                        "Dallas Design District"
                        "Oak Cliff",
                        "River Front",
                        "East Dallas",
                        "South Side",
                        "Cedars",
                        "Deep Ellum",
                        "South Fair Park",
                        "Highland Park",
                        "Cedar Crest"],
    "Zip Code": [75201, 75202, 75207, 75246, 75204, 75212, 75203, 75208, 75256, 75210, 75215, 75226, 75223, 75205, 75216],
    "Total Reported Crimes 2018": [3102, 1837, 1045, 275, 3091, 2139, 1717, 1996, 275, 1710, 4131, 2474, 1037, 224, 5683]
})

dallas_crimes_per_zip
# Out:
#                                       Dallas District  Zip Code  \
# 0   Uptown / Main Street District / Dallas Farmers...     75201
# 1                              Dallas Design District     75202
# 2                                              Baylor     75207
# 3                                Dallas Arts District     75246
# 4                                         West Dallas     75204
# 5                                           Oak Cliff     75212
# 6                     Dallas Design DistrictOak Cliff     75203
# 7                                         River Front     75208
# 8                                         East Dallas     75256
# 9                                          South Side     75210
# 10                                             Cedars     75215
# 11                                         Deep Ellum     75226
# 12                                    South Fair Park     75223
# 13                                      Highland Park     75205
# 14                                        Cedar Crest     75216
#
#     Total Reported Crimes 2018
# 0                         3102
# 1                         1837
# 2                         1045
# 3                          275
# 4                         3091
# 5                         2139
# 6                         1717
# 7                         1996
# 8                          275
# 9                         1710
# 10                        4131
# 11                        2474
# 12                        1037
# 13                         224
# 14                        5683

# %%
zip_divisor1 = dallas_crimes_per_zip['Total Reported Crimes 2018'].sum()
zip_numerator1 = dallas_crimes_per_zip['Total Reported Crimes 2018']
crime_rate1 = (zip_numerator1 / zip_divisor1) * 100
dallas_crimes_per_zip[" Crime Rate (%)" ] = crime_rate1
dallas_crimes_per_zip
# Out:
#                                       Dallas District  Zip Code  \
# 0   Uptown / Main Street District / Dallas Farmers...     75201
# 1                              Dallas Design District     75202
# 2                                              Baylor     75207
# 3                                Dallas Arts District     75246
# 4                                         West Dallas     75204
# 5                                           Oak Cliff     75212
# 6                     Dallas Design DistrictOak Cliff     75203
# 7                                         River Front     75208
# 8                                         East Dallas     75256
# 9                                          South Side     75210
# 10                                             Cedars     75215
# 11                                         Deep Ellum     75226
# 12                                    South Fair Park     75223
# 13                                      Highland Park     75205
# 14                                        Cedar Crest     75216
#
#     Total Reported Crimes 2018   Crime Rate (%)
# 0                         3102        10.092400
# 1                         1837         5.976705
# 2                         1045         3.399922
# 3                          275         0.894716
# 4                         3091        10.056611
# 5                         2139         6.959266
# 6                         1717         5.586283
# 7                         1996         6.494014
# 8                          275         0.894716
# 9                         1710         5.563509
# 10                        4131        13.440265
# 11                        2474         8.049193
# 12                        1037         3.373894
# 13                         224         0.728787
# 14                        5683        18.489719

# %%
# Bar Graph Test [Is Not Final Visual] [Just want to see what data looks like]
zipcodes = dallas_crimes_per_zip["Dallas District"]
crimes = dallas_crimes_per_zip["Total Reported Crimes 2018"]
x_axis = np.arange(len(crimes))
plt.bar(x_axis, crimes, color="b", align="center")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, zipcodes, rotation="vertical")
plt.xlim(-1, len(x_axis))
plt.ylim(0, max(crimes)+ 100)

plt.title("Dallas Districts Total Crime Rate for 2018 ")
plt.xlabel("Zip Codes")
plt.ylabel("Number of Crimes")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dallas_type_crime = dallas_crime_df["Type of Crime"].value_counts()
dallas_type_crime
# Out:
# BMV                                                                  7885
# PUBLIC INTOXICATION                                                  4641
# WARRANT HOLD (OUTSIDE AGENCY)                                        3951
# UNAUTHORIZED USE OF MOTOR VEH - AUTOMOBILE                           3884
# ALARM INCIDENT REPORT (NO OFFENSE)                                   3638
# CRIM MISCHIEF > OR EQUAL $100 < $750                                 3568
# CRIMINAL TRESPASS WARNING                                            3395
# FOUND PROPERTY (NO OFFENSE)                                          3196
# WARRANT-DALLAS PD (ALIAS/CAPIAS)                                     2335
# ABANDONED PROPERTY (NO OFFENSE)                                      2319
# BURGLARY OF BUILDING - FORCED ENTRY                                  2146
# BURGLARY OF HABITATION - FORCED ENTRY                                2045
# ROBBERY OF INDIVIDUAL (AGG)                                          1961
# ASSAULT -BODILY INJURY ONLY                                          1655
# UNAUTHORIZED USE OF MOTOR VEH - TRUCK OR BUS                         1650
# THEFT OF PROP > OR EQUAL $100 <$750 (NOT SHOPLIFT) PC31.03(e2A)      1619
# RECOVERED OUT OF TOWN STOLEN VEHICLE (NO OFFENSE)                    1522
# POSS MARIJUANA <2OZ                                                  1320
# ASSAULT -OFFENSIVE CONTACT                                           1317
# CRIM MISCHIEF >OR EQUAL $750 < $2,500                                1261
# RECKLESS DAMAGE                                                      1245
# ASSAULT (AGG) -DEADLY WEAPON                                         1238
# TRAF VIO -DUTY ON STRIKE UNATTENDED VEH > OR EQUAL $200              1108
# BURGLARY OF HABITATION -NO FORCED ENTRY                              1070
# HARASSMENT                                                           1031
# DWI                                                                   962
# INJURED PERSON- PUBLIC PROPERTY (OTHER THAN FIREARM) (NO OFFENSE)     960
# THEFT OF PROP > OR EQUAL $750 <$2,500 (NOT SHOPLIFT) PC31.03(e3)      909
# ROBBERY OF BUSINESS (AGG)                                             896
# CRIMINAL TRESPASS                                                     857
#                                                                      ...
# EXHIBITION OF FIREARMS (SCHOOL)                                         1
# THEFT OF PROP (AUTO ACC) <$100 ENH (BY EMP) PC31.03(f)                  1
# POSS CONT SUB PEN GRP 2 > OR EQUAL 1G *DRUG FREE ZONE*                  1
# TERRORISTIC THREAT AGAINST PUBLIC SERVANT                               1
# THEFT TELECOM SER > OR EQUAL $500 BUT <$1,500                           1
# MAN DEL CONT SUB PEN GRP 1A > OR EQUAL 20<80AU                          1
# FRAUD POSS CS/PRESCRIPTION SCH I, II                                    1
# DELIVERY OR OFFER OF DELIVERY OF DANGEROUS DRUG                         1
# TERRORISTIC THREAT IMPAIR PUBLIC SER/PUBLIC FEAR SBI/INFLU GOV          1
# THEFT OF PROP (ATT) $100 BUT <$750 ENH (NOT EMPLOYEE)                   1
# TRADEMARK COUNTERFEITING <$100                                          1
# THEFT OF PROP (ATT) <$2,500 2+CONV ENH (NOT EMP) PC31.03(f)             1
# ACCIDENT INVOLVING DEATH                                                1
# ESCAPE CAUSE BODILY INJURY                                              1
# THEFT OF PROP <$100 ENH (SHOPLIFT-NOT EMP) PC31.03(f)                   1
# TAKE WEAPON FROM AN OFFICER (GUN OR BATON)                              1
# THEFT OF PROP (AUTO ACC) $750 BUT <$2500 ENH - (NOT EMP)                1
# UNLAWFUL CARRY HANDGUN LIC HOLDER ALCH PREM/CORR FAC                    1
# UCR- UUMV-NO CODE                                                       1
# TRAF VIO -MAKE/POSS CFT INSP RPT/INS DOC INTD HARM/DEFRAUD              1
# THEFT OF PROP (ATT) > OR EQUAL $100 BUT <$750 (NOT EMP                  1
# ILLEGAL DUMPING IN CLOSED BARREL OR DRUM HSC 365.012(g)(3)              1
# THEFT OF PROP > OR EQUAL $300K (SHOPLIFT-NOT BY EMP) PC31.03(e7)        1
# LEWD/IMMORAL/INDECENT CONDUCT                                           1
# CRUELTY TO NON-LIVESTOCK ANIMALS: FAILURE TO PROVIDE FOR                1
# UCR - BMV- STOLEN PROP/DAMAGE COLUMN/IGNITION -OTHER                    1
# VIO PROTECT ORDER BIAS/PREJUD W/2+ PREV CONV.                           1
# FALSE STATEMENT FOR PROPERTY/CREDIT > $150K < $300K PC32.32(c6)         1
# THEFT OF CARGO > OR EQUAL $100K < $200K (EMP) PC31.18(c3)               1
# FRAUD POSS CS/PRESRCIPTION SCH IV OR V                                  1
# Name: Type of Crime, Length: 549, dtype: int64

# %%
txzips = "Resources/txzipslatlong.csv"
zip_lat_long_data = pd.read_csv(txzips, encoding="utf-8")
#zip_lat_long_data.head()

incidents_zip_lat_long_df= pd.merge(dallas_crimes_per_zip,zip_lat_long_data, how='left', left_on=['Zip Code'], right_on=['zip'])
incidents_zip_lat_long_df
# Out:
#                                       Dallas District  Zip Code  \
# 0   Uptown / Main Street District / Dallas Farmers...     75201
# 1                              Dallas Design District     75202
# 2                                              Baylor     75207
# 3                                Dallas Arts District     75246
# 4                                         West Dallas     75204
# 5                                           Oak Cliff     75212
# 6                     Dallas Design DistrictOak Cliff     75203
# 7                                         River Front     75208
# 8                                         East Dallas     75256
# 9                                          South Side     75210
# 10                                             Cedars     75215
# 11                                         Deep Ellum     75226
# 12                                    South Fair Park     75223
# 13                                      Highland Park     75205
# 14                                        Cedar Crest     75216
#
#     Total Reported Crimes 2018   Crime Rate (%)      zip       lat       lng
# 0                         3102        10.092400  75201.0  32.78780 -96.79948
# 1                         1837         5.976705  75202.0  32.77924 -96.80472
# 2                         1045         3.399922  75207.0  32.78676 -96.82139
# 3                          275         0.894716  75246.0  32.79292 -96.77330
# 4                         3091        10.056611  75204.0  32.80205 -96.78882
# 5                         2139         6.959266  75212.0  32.78137 -96.87917
# 6                         1717         5.586283  75203.0  32.74625 -96.80301
# 7                         1996         6.494014  75208.0  32.75373 -96.83986
# 8                          275         0.894716      NaN       NaN       NaN
# 9                         1710         5.563509  75210.0  32.77135 -96.74596
# 10                        4131        13.440265  75215.0  32.75075 -96.75806
# 11                        2474         8.049193  75226.0  32.78278 -96.77641
# 12                        1037         3.373894  75223.0  32.79223 -96.74399
# 13                         224         0.728787  75205.0  32.83656 -96.79623
# 14                        5683        18.489719  75216.0  32.71162 -96.78369

# %%
incidents_zip_lat_long_df = incidents_zip_lat_long_df.dropna(how='any')
incidents_zip_lat_long_df.count()
incidents_zip_lat_long_df
# Out:
#                                       Dallas District  Zip Code  \
# 0   Uptown / Main Street District / Dallas Farmers...     75201
# 1                              Dallas Design District     75202
# 2                                              Baylor     75207
# 3                                Dallas Arts District     75246
# 4                                         West Dallas     75204
# 5                                           Oak Cliff     75212
# 6                     Dallas Design DistrictOak Cliff     75203
# 7                                         River Front     75208
# 9                                          South Side     75210
# 10                                             Cedars     75215
# 11                                         Deep Ellum     75226
# 12                                    South Fair Park     75223
# 13                                      Highland Park     75205
# 14                                        Cedar Crest     75216
#
#     Total Reported Crimes 2018   Crime Rate (%)      zip       lat       lng
# 0                         3102        10.092400  75201.0  32.78780 -96.79948
# 1                         1837         5.976705  75202.0  32.77924 -96.80472
# 2                         1045         3.399922  75207.0  32.78676 -96.82139
# 3                          275         0.894716  75246.0  32.79292 -96.77330
# 4                         3091        10.056611  75204.0  32.80205 -96.78882
# 5                         2139         6.959266  75212.0  32.78137 -96.87917
# 6                         1717         5.586283  75203.0  32.74625 -96.80301
# 7                         1996         6.494014  75208.0  32.75373 -96.83986
# 9                         1710         5.563509  75210.0  32.77135 -96.74596
# 10                        4131        13.440265  75215.0  32.75075 -96.75806
# 11                        2474         8.049193  75226.0  32.78278 -96.77641
# 12                        1037         3.373894  75223.0  32.79223 -96.74399
# 13                         224         0.728787  75205.0  32.83656 -96.79623
# 14                        5683        18.489719  75216.0  32.71162 -96.78369

# %%
gmaps.configure(api_key=gkey)

locations = incidents_zip_lat_long_df[["lat", "lng"]].astype(float)
crime_rate = incidents_zip_lat_long_df["Total Reported Crimes 2018"].astype(float)
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=crime_rate, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = .005)

heat_layer.dissipating = False
heat_layer.max_intensity = 100
heat_layer.point_radius = .005
#heat_layer.zoom = -1

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
bank_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=[f"Bank amount: {bank}" for bank in bank_rate]
)


fig = gmaps.figure()
fig.add_layer(bank_layer)

fig
